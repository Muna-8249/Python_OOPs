# %% [markdown]
# 1.  What is Object-Oriented Programming (OOP)?
#
#     - Object-Oriented Programming (OOP) is a programming approach that organizes code  into objects, which combine data (attributes) and behavior (methods) into a single unit. It helps code more modular, reusable, and easier to maintain.

# %% [markdown]
# 2.  What is a class in OOP?
#
#     - In OOPs class is a fundamental concept that serves as a blueprint or template for creating objects. It defines the structure and behavior that objects of a perticular type will possess.

# %% [markdown]
# 3.  What is an object in OOP?
#
#     - An object is an instance of a class. it is a real world entity that has data (attrubutes) and behaviors (method) defined by its class. For example, if "Dog" is a class, then "Buddy" and "Max" could be individual object (instances)of the Dog class.

# %% [markdown]
# 4.  What is the difference between abstraction and encapsulation?
#
#     ##### - Abstraction hides implementation details to show only the essential features of an objects, while encapsulation bundles data and methods together to protect the data from outside access.
#
# #### Abstraction
#     - what is it: A proces of hiding complex implementation details and showing only the necessary functionality to the user.
#     - Focus: Hiding the "How" to expose the "What".
#     - How it works: Achived through abstractclasses and interfaces, which define a contract for what an object can do without revealing the underlying code.
#     - Analogy: A car steering wheel and pedal. You know how to use them to drive, but you do not need to know the complex mechanism of the engine or steering system to operate them.
#
# #### Encapsulation
#     - What is it: The bunding of attributes and the methods that operate on that data into a single class.
#     - Focus: Protecting the internal state of an object from direct, unauthorized access.
#     - How it works: Achieved by making data members private and providing public getter and setter methods to control access.
#     - Analogy: A car engine is hidden under the hood. you can not directly access and temper with the internal components, but you can use the accelerator pedal to control its speed.

# %% [markdown]
# 5.  What are dunder methods in Python?
#
#     - Dunder methods are methods that start and end with double underscores (__method__). They allow us to define or customize behavior of our objects for built-in operations.
#
# #### Here are some common examples and their uses:
#
#     1. __init__(self, ...): Constructer method, called automatically when new instance of a class is created. it's used to initialize the objects attributes.
#     2. __str__(self): Define the informal string representation of an object tipically for user-friendly display when using print().
#     3. __add__(self, ...): Implements the behavior of the + operator for instance of your class.
#     4. __len__(self): Returning the length of an objects etc.

# %% [markdown]
# 6.  Explain the concept of inheritance in OOP.
#
#     - Inheritance is a is a concept where one class (child class) can inherit properties and methods from another class (parent class). It allows code reusability and it helps to build a hierarchy of classes.
#
#     #### Key Concept:
#         ###### Parent Class: Thev existing that is being inherited from. It contains the properties and methods that are common toa group of class.
#
#         ###### Child/Derived class: The new class that inherites from the parent class. It can reuse the parents code and also add its own unique attributes and methods.
#
#         ###### Is a Relationship: A fundamental way to model real world objectsFor instance Dog is an animal, so a dog class can inherit from an animal class.
#
#         ###### Code reusability: Avoide redundant code by allowing the child class to simply use the parents features without rewriting them.
#
#         ###### Extensibility: The child class can add new behaviors or modify inherited ones througth a process called method overriding without changing the parrent class.

# %% [markdown]
# 7.  What is Polymorphism in OOP?
#
#      - Polymorphism is a core oop concept where an object can take on multiple forms, allowing a single interface to be use for different type of objects.
#
# #### Key Concept:
#     1. Many forms
#     2. Single Interface
#     3. Behavioral differences
#
# #### Types of Polymorphism:
#     - Method Overloading
#     - Method Overriding

# %% [markdown]
# 8.  How is encapsulation achieved in Python?
#
#     - Encapsulation is the concepts of hiding the internal state (Data) of an object and only allowing it to be accessed or modified through methods.
#
# #### How Encapsulation is Achieved in Python:
#     Python uses access modifiers to control visibility
#         1. Public- Accessible from anywhere
#         2. Protected-by convention, single underscore_(meant for internal use only, but still accessible)
#         3. Private- double underscore__(Strongly suggest do not touch from outside)

# %% [markdown]
# 9.  What is a constructor in Python?
#
#     - A Python constructor is a special method used to initialize a newly created object of a class. It is automatically called when an object of a class is created. The primary objects of a constructor is to setup the initial state of the object by assigning value to its attributes.
#     - Python uses the dunder method __init__() as a constructor and its called automatically when an object is created.

# %% [markdown]
# 10. What are class and static methods in Python?
#
#     - In Python, both methods are type of methods defined within a class, but they differ in how they interact with the class and its instances.
#
# #### Class Methods:
#     - Bound to the Class: Class methods are associated with the class itself, not with a specific instances.
#     - First parameter cls: Take the class object (cls) as first parameter, which allows to access and modify class-level attribute and call other class methods.
#     - Decorator: Defined using the @classmethod decorator.
#
# #### Static Methods:
#     - Not bound to the Class: Static methods are essentially regular functions that happen to be defined within a class. It does not receive self or cls as first argument.
#     - No special first parameter: Do not automatically receive a reference to the class or instance.
#     - Decorator: Define using the Static Method.

# %% [markdown]
# 11. What is method overloading in Python?
#
#     - Method Overloading is a concept where multiple methods in a same class have the same name but different parameter. It allows the same method to behave differently based on the number or type of arguments.
#
#     - Python does not support traditional method overloading like Java or C++, if we define multiple methods with the same name, the last one  will override the previous ones, but we can achieve similar behavior using:-
#
#         a. Default arguments
#
#         b.*args and **kwargs

# %% [markdown]
# 12. What is method overriding in OOP?
#
#     - Method Overriding happens when a child calss redifines a method that is already defined in its parent class, same method name and same parameters, different behavior in child class
#
# #### Key Aspects:
#     - Inheritance
#     - Same name and signature
#     - Polymorphism
#     - super() Function

# %% [markdown]
# 13. What is a property decorator in Python?
#
#     - A property decorator in python, specially @property. It is a built-in decorator that allows us to define methods within a class that can be accessed like attributes.
#     - It provides a way to manage attribute access getting setting and deleting values in a controlled and pythonic manner, promoting encapsulation and data integrity.

# %% [markdown]
# 14. Why is polimorphism important in OOP?
#
#     - Polymorphism is important in oop because it enables, flexibility, code reusability by allowing objects of different classes to be treated as objects of a common superclass. This makes code more adaptable and easier to maintain by enabling a single interface to work with various ibject types without changing exising code.

# %% [markdown]
# 15. What is an abstract class in Python?
#
#     - An abstract class in python is a class that cannot be instantiated on its own. It serves as a blue print for other class and usually contains one or more abstract methods that that must be implemented by its subclasses.
#
# #### Key Points:
#     - Use ABC from abc module to create an abstract ckass.
#
#     - Abstract methods are defined with @abstractmethod decorator

# %% [markdown]
# 16. What are the advantages of OOP?
#
# #### Advantages of OOP
#
#     - Modularity: Code is organised into classes and objects, making it easier to manage.
#
#     - Reusability: Through inheritance, we can reuse existing code instead of writing it again.
#
#     - Encapsulation: Keep data safe by restricting direct access and controlling via methods
#
#     - Polymorphism: Same method name work can different for different object, making code flexible.
#
#     - Abstraction: Hides complex implementation details and expose only essential features.
#
#     - Easy maintenance: Modular code is easier to update and debug.
#
#     - Realworld modeling: Objects represent real world entitles making design intuitive.

# %% [markdown]
# 17. What is the difference between a class variable and an instance variable?
#
#     - The distinction between class variables and instance variables is fundamental to understanding object orriented programming:
#
# #### Class Variable
#
#     * Definition:  A class varible is shared among all objects of the class and it is defined outside the constructor, but inside the class.
#
#     * Purpose: class varible are typically used for attrubutes that are common to all objects of a class, such as constants, default values, or counters for the number of instance created.
#
#     * Memory: Only one copy exists for the entire class. If changed via class name, it affects all the objects.
#
# #### Instance Varible
#
#     * Definition: Instance varibles are defined within the methods of a class, typically within the __init__method using the self keyword. They are unique to each instance of the class.
#
#     * Purpose: Instance variables are used to store data that is specific to each individual object, representing its unique state or characteristics.
#
#     * Memory: Each object gets its own copy of instance variables. Cganging it in one object doesnot affect others.

# %% [markdown]
# 18. What is multiple inheritance in Python?
#
#     - Multiple inheritance in python is a feature where a class can inherit attributes and methods from more than one parent class. This allows a derived class to combined the functionality of multiple base classes.

# %% [markdown]
# 19. Explain the purpose of " _ _str__ " and " _ _repr__ " methods in Python.
#
#     - In python, '__str__' and '__repr__' are special methods (often called 'dunder methods' due to their double underscores) that define how an object is represented as a string. They serve different purposes and are aimed at different audiance.
#
# #### __ str__ (For Users)
#
#     * This method provides an informal, human-readable string representation of an object.
#     * Its primary goal is readability and to present information in a way that is easy for end-users to understand.
#     * It is invoked by functions like print() and str(), and also used implicitly in f-strings and other contexts where a user-friendly string is desired.
#     * The output of __str__ is not necessarily intended to be valid Python code.
#
# #### __ repr__ (For Developer)
#
#     * This method provides an official unambiguous string representation of an object.
#     * Its primary goal is to aid debugging and development, offering a detailed representation that ideally could be used to create the object.
#     * It is invoked by the repr() function and by the python interactive interpreter when an object is evaluted directly.
#     * The output of __repr__ should ideally be a valid python expression that, when passed to eval().

# %% [markdown]
# 20. What is the significance of the "super()" function in Python?
#
#     - The super() function in python holds significant important within the context of OOP, perticularly concerning inheritance. Its primary significance lies in enabling subclasses to effectivly interact with their parent or super class.
#
# #### Key Role:
#     * Calling Parent class methods: super allows a child class to call methods defined in its parent class.
#     * Maintaining Method Resolution Order: In scenarios involving multiple inheritance, where a class inherits from multiple parent classes, super() plays a vital in adhering to the Method Resolution Order (MRO).
#     * Promoting code flexibility and maintainability: By using super(), a child class can call parent methods without explicitly referencing the parent class name. This makes the code more flexible and easier to maintain especially when refactoring or changing the inheritance hirarchy
#     * Enhancing Readability and Extensibility: super() promotes a cleaner and more organized approach to class construction within inheritance. It makes the intent of calling a parent method explicit, improving code readability.

# %% [markdown]
# 21. What is the significance of the _ _del_ _ method in Python?
#
#     - __del__ is a destructor method in python.Its automatically called when an object is about to be destroyed, i.e., just before python deletes it from its memory.
#     - __init__() is Constructor and __del__ is Destructor.

# %% [markdown]
# 22. What is the difference between @staticmethod and @classmethod in Python?
#
#     - The @staticmethod and @classmethod decorators in Python define different types of methods within a class, primarily distinguished by their access to instance and class attributes.
#
# #### @staticmethod:
#
#     * Definition: Defines a method that doesnot operate on instance or class, it behaves just like a normal function inside a class.
#
#     * First Argument: No default first argument.
#
#     * Access: Can not access or modify class or instance attribute.
#
#     *  Usage: When we don't need to know anything about the class or instance.
#
#     * Call Method: Can be called using class name or instance.
#
# #### @classmethod:
#
#     * Definition: Define a method that operates on the class itself rather than its instance.
#
#     * First Argument: Takes 'cls' (class) as the first argument.
#
#     *  Access: Can access and modify class-level attributes(through cls).
#
#     * Usage: When we need to work with class varibles or want to define an alternative constructor.
#
#     * Call Method: Can be called using class name or instance.

# %% [markdown]
# 23. How does polimorphism work in python with inheritance?
#
#     - Polymorphism in python, when combine with inheritance, primarily menifests through method overriding. This allows objects of different classes, which share a common base class, to be treated uniformly while exibiting specific behaviors defined within their respective classes.
#
# #### How its Works:
#
#     * **Base Class and Derived Class:** A base class defines a common interface (method and attributes). Multiple derived classes (subclasses) inherit from this base class.
#
#     * **Method Overriding:** Derived classes can provide their own implementation for methods that are already defined in the base class. This is called method overriding. When a method is overridden the version in the derived class takes precedence over the version in the  base class for objects of that derived class.
#
#     * **Common Interface, Diverse Behavior:** Because all derived classes inherit from a common base class , they can be treated as instance of that base class. This allows you to write code that interacts with objects through the base class interface, even though the specific behavior of a method might differ in each derived class due to overriding.

# %% [markdown]
# 24. What is method chaining in Python OOP?
#
#     - Method chaining in python OOP is a programming technique that allows for multiple method calls to be invoked sequentially on the same object in a single concise expression. This is achieved by having each method in the chain return the object itself(Usually self).
#
# #### How its Works:
#
#     * **Method Definition:** In a class, methods designed for chaining perform their respective operations and then explicitly return 'self'.
#
#     * **Sequential Invocation:** When an object calls the first method in a chain, that method executes and return the object. This returned object then immediately calls the next method in the chain and so on.

# %% [markdown]
# 25. What is the purpose of the _ _call_ _ method in Python?
#
#     - The __ call__ method in python, also known as the "call" method, enable instance of a class to be called like functions. When we define __ call__ within a class , objects created from that class become "callable" objects.
#
# #### Purpose of __ call__ method:
#
#     * **Making Object Callable:** The primary purpose is to allow instance of a class to be invoked directly using parentheses, just like a regular function.
#
#     * **Create Function-like Objects with State:** __ call__ is useful for creating objects that maintain internal state while behaving like functions. This allows for more advanced patterns like:
#         - Decorators with State: To warp the decorated function and also store information.
#         - Factories or Generators: To perform the generation/processing when invoked.
#         - API Clints: To handle requests, logging and responce parsing when the clint object is called with specific API endpoints and parameter.

# %% [markdown]
# ## Practical Questions

# %% [markdown]
# 1.  Create a parent class Animal with a method speak() that prints a generic message. Create a child class Dog that overrides the speak() method to print "Bark!".

# %%
class Animal:
    def speak(self):
        print("The animal sound makes a sound")

class Dog(Animal):
    def speak(self):
        print("Bark!")

My_dog = Dog()
My_dog.speak()
# Out:
# Bark!

# %% [markdown]
# 2.  Write a program to create an abstract class Shape with a method area(). Derive classes Circle and Rectangle from it and implement the area() method in both.

# %%
from abc import ABC, abstractmethod
class Shape(ABC):
    @abstractmethod
    def area(self):
        pass

class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def area(self):
        return 3.14 * (self.radius ** 2)

class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def area(self):
        return self.length * self.width

circle = Circle(5)
rectangle = Rectangle(4, 6)

print("Area of Circle is:", circle.area())
print("Area of Rectangle is:", rectangle.area())
# Out:
# Area of Circle is: 78.5
# Area of Rectangle is: 24

# %% [markdown]
# 3.  Implement a multi-level inheritance scenario where a class Vehicle has an attribute type. Derive a class Car and further Derive a class ElectricCar that adds a battery attribute.

# %%
class Vehicle:
    def __init__(self, vehicle_type):
        self.vehicle_type = vehicle_type

    def show_type(self):
        print(f"Vehicle type: {self.vehicle_type}")

class Car(Vehicle):
    def __init__(self, vehicle_type, brand):
        super().__init__(vehicle_type)
        self.brand = brand

    def show_brand(self):
        print(f"Car Brand: {self.brand}")

class ElectricCar(Car):
    def __init__(self, vehicle_type, brand, battery_capacity):
        super().__init__(vehicle_type, brand)
        self.battery_capacity = battery_capacity

    def show_details(self):
        self.show_type()
        self.show_brand()
        print(f"Battery Capacity: {self.battery_capacity} kWh")

TaTa = ElectricCar("Four wheeler", "TaTa motors", 110)
TaTa.show_details()
# Out:
# Vehicle type: Four wheeler
# Car Brand: TaTa motors
# Battery Capacity: 110 kWh

# %% [markdown]
# 4.  Demonstrate polymorphism by creating a base class Bird with a method fly(). Create two derived classes Sparrow and Penguin that override the fly() method.

# %%
class Bird:
    def fly(self):
        print("Most birds can fly in the sky.")

class Eagle(Bird):
    def fly(self):
        print("Eagle can flies high and fast.")

class Penguin(Bird):
    def fly(self):
        print("Penguin cannot fly in the sky, but they swim very well.")

def show_fly(bird):
    bird.fly()

eagle = Eagle()
penguin = Penguin()

show_fly(eagle)
show_fly(penguin)
# Out:
# Eagle can flies high and fast.
# Penguin cannot fly in the sky, but they swim very well.

# %% [markdown]
# 5.  Write a program to demonstrate encapsulation by creating a class BankAccount with Private attributes balance and methods to Deposit, Withdraw, and check Balance.

# %%
class BankAccount:
    def __init__(self, account_holder, balance=0):
        self.__account_holder = account_holder
        self.__balance = balance

    def deposit(self, amount):
        if amount > 0:
            self.__balance += amount
            print(f"${amount} deposited successfully!")
        else:
            print("Invalid deposit amount")

    def withdraw(self, amount):
        if 0 < amount <= self.__balance:
            self.__balance -= amount
            print(f"${amount} withdrawn successfully!")
        else:
            print("Invalid withdrawal amount or insufficient balance")

    def check_balance(self):
        print(f"Account Holder: {self.__account_holder}")
        print(f"Available Balance: ${self.__balance}")

Padmalochan_account = BankAccount("Padmalochan", 10000)
Padmalochan_account.deposit(5000)
Padmalochan_account.withdraw(2000)
Padmalochan_account.check_balance()
# Out:
# $5000 deposited successfully!
# $2000 withdrawn successfully!
# Account Holder: Padmalochan
# Available Balance: $13000

# %% [markdown]
# 6.  Demonstrate runtime polymorphism using a method play() in a base class instrument. Derive classes Guitar and Piano that implememt their own version of play().

# %%
class Instrument:
    def play(self):
        raise NotImplementedError("Child class must implement the play() method")

class Guitar(Instrument):
    def play(self):
        print("Guitar: strum strum!")

class Piano(Instrument):
    def play(self):
        print("Piano: ding ding!")

# %%
instruments = [Guitar(), Piano()]

for instrument in instruments:
    instrument.play()
# Out:
# Guitar: strum strum!
# Piano: ding ding!

# %% [markdown]
# 7.  Create a class MathOperations with a class method add_numbers() to add two numbers and a static method subtract_numbers() to subtract two numbers.

# %%
class MathOperations:
    @classmethod
    def add_numbers(cls, a, b):
        return a + b
    @staticmethod
    def subtract_numbers(a, b):
        return a - b

# %%
print("Addition:", MathOperations.add_numbers(5, 9))

print("Subtraction:", MathOperations.subtract_numbers(10, 4))
# Out:
# Addition: 14
# Subtraction: 6

# %% [markdown]
# 8.  Implement a class Person with a class method to count the total number of persons created.

# %%
class Person:
    count = 0

    def __init__(self, name):
        self.name = name
        Person.count += 1

    @classmethod
    def total_persons(cls):
        return cls.count

# %%
person1 = Person("Padmalochan")
person2 = Person("Muna")
person3 = Person("Ram")

print("Total persons created:", Person.total_persons())
# Out:
# Total persons created: 3

# %% [markdown]
# 9. Write a class Fraction with attributes numerator and denominator. Override the str method to display the fraction as "numerator/denominator".

# %%
from math import gcd

class Fraction:
    def __init__(self, numerator, denominator):
        if denominator == 0:
            raise ValueError("Denominator cannot be zero")

        g = gcd(numerator, denominator)
        self.numerator = numerator //g
        self.denominator = denominator //g

    def __str__(self):
        return f"{self.numerator}/{self.denominator}"

# %%
f = Fraction(12, 16)
print(f)
# Out:
# 3/4

# %% [markdown]
# 10. Demonstrate operator overloading by creating a class Vector and Overriding the add method to add two vectors.

# %%
class Vector:
    def __init__(self, x, y):
        self.x = x
        self.y = y

    def __add__(self, other):
        if not isinstance(other, Vector):
            return NotImplemented
        return Vector(self.x + other.x, self.y + other.y)

    def __repr__(self):
        return f"Vector({self.x}, {self.y})"

# %%
v1 = Vector(1, 2)
v2 = Vector(3, 4)
v3 = v1 + v2
print(v3)
# Out:
# Vector(4, 6)

# %% [markdown]
# 11. Create a class person with attributes name and age. add a method greet() that prints "Hello, my name is {name} and i am {age} years old."

# %%
class Person:
    def __init__(self, name, age):
        self.name = name
        self.age = age

    def greet(self):
        print(f"Hello, my name is {self.name} and I am {self.age} years old.")

# %%
p = Person("Padmalochan", 32)
p.greet()
# Out:
# Hello, my name is Padmalochan and I am 32 years old.

# %% [markdown]
# 12. Implement a class Student with attributes name and grades. Crete a method average_grade() to compute the average of the grades.

# %%
class Student:
    def __init__(self, name, grades):
        self.name = name
        self.grades = list(grades)

    def average_grade(self):
        if not self.grades:
            return 0.0
        return sum(self.grades) / len(self.grades)

# %%
S = Student("Padmalochan", [90, 85, 92, 85, 69, 75])
print(f"Average Grade is: {S.average_grade()}")
# Out:
# Average Grade is: 82.66666666666667

# %% [markdown]
# 13. Create a class Rectangle with methods set_dimensions() to set the dimensions and area() to calculate the area.

# %%
class Rectangle:
    def set_dimensions(self, width, height):
        self.width = width
        self.height = height

    def area(self):
        return self.width * self.height

rect = Rectangle()
rect.set_dimensions(5, 10)
print("Area of Rectangle is:", rect.area())
# Out:
# Area of Rectangle is: 50

# %% [markdown]
# 14. Create a class Employee with a methods calculate_salary() that computes salary based on hours worked and hourly rate . Create a derived class Manager that adds a bonus to the salary.

# %%
# Parent class
class Employee:
    def __init__(self, hours_worked, hourly_rate):
        self.hours_worked = hours_worked
        self.hourly_rate = hourly_rate

    def calculate_salary(self):
        return self.hours_worked * self.hourly_rate

# Derived class
class Manager(Employee):
    def __init__(self, hours_worked, hourly_rate, bonus):
        super().__init__(hours_worked, hourly_rate)
        self.bonus = bonus

    def calculate_salary(self):
        base_salary = super().calculate_salary()
        return base_salary + self.bonus

emp = Employee(100, 200)
print("Employee Salary:", emp.calculate_salary())

mgr = Manager(100, 200, 5000)
print("Manager Salary:", mgr.calculate_salary())
# Out:
# Employee Salary: 20000
# Manager Salary: 25000

# %% [markdown]
# 15. Create a class Product with attributes name , price, and quantity. Implement a method total_price() that calculates the total price of the product.

# %%
class Product:
    def __init__(self, name, price, quantity):
        self.name = name
        self.price = price
        self.quantity = quantity

    def total_price(self):
        return self.price * self.quantity

p = Product("Laptop", 50000, 5)
print("Product Name:", p.name)
print("Total Price:", p.total_price())
# Out:
# Product Name: Laptop
# Total Price: 250000

# %% [markdown]
# 16. Create a class Animal with an abstract method sound(). Create two derived classes Cow and Sheep that implement sound() method.

# %%
from abc import ABC, abstractmethod

class Animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class Cow(Animal):
    def sound(self):
        print("Haammmaaaa....!")

class Sheep(Animal):
    def sound(self):
        print("Bhheeeee....!")

C = Cow()
S = Sheep()

C.sound()
S.sound()
# Out:
# Haammmaaaa....!
# Bhheeeee....!

# %% [markdown]
# 17. Create a class Book with attributes title, author, and year_published. Add a method get_book_info() that returns a formatted string with the books details.

# %%
class Book:
    def __init__(self, title, author, year_published):
        self.title = title
        self.author = author
        self.year_published = year_published

    def get_book_info(self):
        return f"Title: {self.title}, Author: {self.author}, Year Published: {self.year_published}"

B = Book("Python Basics", "John Doe", 2021)
print(B.get_book_info())
# Out:
# Title: Python Basics, Author: John Doe, Year Published: 2021

# %% [markdown]
# 18. Create a class House attributes address and price. Create a derived class Mansion that adds an attribute number_of_rooms.

# %%
class House:
    def __init__(self, address, price):
        self.address = address
        self.price = price

class Mansion(House):
    def __init__(self, address, price, number_of_rooms):
        super().__init__(address, price)
        self.number_of_rooms = number_of_rooms

    def info(self):
        return f"Address: {self.address}, Price: {self.price}, " f"Rooms: {self.number_of_rooms}"

M = Mansion("Keonjhar, Odisha", 30000000, 12)
print(M.info())
# Out:
# Address: Keonjhar, Odisha, Price: 30000000, Rooms: 12

# %% [markdown]
#                                                .............end.............
